# %%
import pandas as pd
import numpy as np
data = pd.read_csv("pub.csv")
data
# Out:
#    Componente ambiental            matriz  ... Sulfotep Thionazin
# 0                  Agua  Agua subterránea  ...        -         -
# 1                  Agua  Agua subterránea  ...        -         -
# 2                  Agua  Agua subterránea  ...        -         -
# 3                  Agua  Agua superficial  ...        -         -
# 4                  Agua  Agua superficial  ...       <3        <1
# 5                  Agua  Agua superficial  ...        -         -
# 6                  Agua  Agua superficial  ...        -         -
# 7                  Agua  Agua superficial  ...        -         -
# 8                  Agua  Agua superficial  ...        -         -
# 9                  Agua  Agua superficial  ...       <3        <1
# 10                 Agua  Agua superficial  ...       <3        <1
# 11                 Agua  Agua superficial  ...        -         -
# 12                 Agua  Agua superficial  ...        -         -
# 13                 Agua  Agua superficial  ...        -         -
# 14                 Agua  Agua superficial  ...        -         -
# 15                 Agua  Agua superficial  ...       <3        <1
# 16                 Agua  Agua superficial  ...        -         -
# 17                 Agua  Agua superficial  ...        -         -
# 18                 Agua  Agua superficial  ...        -         -
# 19                 Agua  Agua superficial  ...       <3        <1
# 20                 Agua  Agua superficial  ...        -         -
# 21                 Agua  Agua superficial  ...       <3        <1
# 22                 Agua  Agua superficial  ...       <3        <1
#
# [23 rows x 132 columns]

# %%
data.drop([5], inplace=True)

# %%
data
# Out:
#    Componente ambiental            matriz  ... Thionazin                geometry
# 1                  Agua  Agua subterránea  ...         -  POINT (202143 8117057)
# 2                  Agua  Agua subterránea  ...         -  POINT (201861 8117035)
# 3                  Agua  Agua superficial  ...         -  POINT (191976 8107277)
# 4                  Agua  Agua superficial  ...        <1  POINT (208989 8111680)
# 6                  Agua  Agua superficial  ...         -  POINT (205234 8110983)
# 7                  Agua  Agua superficial  ...         -  POINT (204791 8103053)
# 8                  Agua  Agua superficial  ...         -  POINT (208707 8110437)
# 9                  Agua  Agua superficial  ...        <1  POINT (196838 8100253)
# 10                 Agua  Agua superficial  ...        <1  POINT (194637 8102351)
# 11                 Agua  Agua superficial  ...         -  POINT (194013 8103214)
# 12                 Agua  Agua superficial  ...         -  POINT (194021 8103169)
# 13                 Agua  Agua superficial  ...         -  POINT (195149 8101837)
# 14                 Agua  Agua superficial  ...         -  POINT (195627 8101417)
# 15                 Agua  Agua superficial  ...        <1  POINT (193667 8103432)
# 16                 Agua  Agua superficial  ...         -  POINT (218955 8119620)
# 17                 Agua  Agua superficial  ...         -  POINT (213482 8115143)
# 18                 Agua  Agua superficial  ...         -  POINT (209962 8112966)
# 19                 Agua  Agua superficial  ...        <1  POINT (207821 8106908)
# 20                 Agua  Agua superficial  ...         -  POINT (204853 8103600)
# 21                 Agua  Agua superficial  ...        <1  POINT (197967 8099495)
# 22                 Agua  Agua superficial  ...        <1  POINT (231651 8115070)
#
# [21 rows x 133 columns]

# %%
tabla_1["matriz"]= "Agua subterranea"

# %%
# !pip install geopandas
# Out:
# Collecting geopandas
#   Downloading https://files.pythonhosted.org/packages/74/42/f4b147fc7920998a42046d0c2e65e61000bc5d104f1f8aec719612cb2fc8/geopandas-0.5.0-py2.py3-none-any.whl (893kB)
#      |████████████████████████████████| 901kB 5.0MB/s
# Collecting fiona (from geopandas)
#   Downloading https://files.pythonhosted.org/packages/89/4a/193cd6a75e51062c85f4e1cd6f312b3bbda6e26ba7510f152ef5016f0b16/Fiona-1.8.6-cp36-cp36m-manylinux1_x86_64.whl (17.9MB)
#      |████████████████████████████████| 17.9MB 40.0MB/s
# Requirement already satisfied: shapely in /usr/local/lib/python3.6/dist-packages (from geopandas) (1.6.4.post2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from geopandas) (0.24.2)
# Collecting pyproj (from geopandas)
#   Downloading https://files.pythonhosted.org/packages/16/59/43869adef45ce4f1cf7d5c3aef1ea5d65d449050abdda5de7a2465c5729d/pyproj-2.2.1-cp36-cp36m-manylinux1_x86_64.whl (11.2MB)
#      |████████████████████████████████| 11.2MB 32.5MB/s
# Collecting munch (from fiona->geopandas)
#   Downloading https://files.pythonhosted.org/packages/68/f4/260ec98ea840757a0da09e0ed8135333d59b8dfebe9752a365b04857660a/munch-2.3.2.tar.gz
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (1.12.0)
# Collecting click-plugins>=1.0 (from fiona->geopandas)
#   Downloading https://files.pythonhosted.org/packages/e9/da/824b92d9942f4e472702488857914bdd50f73021efea15b4cad9aca8ecef/click_plugins-1.1.1-py2.py3-none-any.whl
# Requirement already satisfied: click<8,>=4.0 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (7.0)
# Collecting cligj>=0.5 (from fiona->geopandas)
#   Downloading https://files.pythonhosted.org/packages/e4/be/30a58b4b0733850280d01f8bd132591b4668ed5c7046761098d665ac2174/cligj-0.5.0-py3-none-any.whl
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (19.1.0)
# Requirement already satisfied: python-dateutil>=2.5.0 in /usr/local/lib/python3.6/dist-packages (from pandas->geopandas) (2.5.3)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas->geopandas) (2018.9)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from pandas->geopandas) (1.16.4)
# Building wheels for collected packages: munch
#   Building wheel for munch (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/db/bf/bc/06a3e1bfe0ab27d2e720ceb3cff3159398d92644c0cec2c125
# Successfully built munch
# Installing collected packages: munch, click-plugins, cligj, fiona, pyproj, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.5.0 fiona-1.8.6 geopandas-0.5.0 munch-2.3.2 pyproj-2.2.1

# %%
import pandas as pd
from geopandas import GeoDataFrame
from shapely.geometry import Point
import fiona

# %%
geometry = [Point(xy) for xy in zip(data.Este, data.Norte)]
crs={"init":"epsg:32719"}

# %%
geo_df = GeoDataFrame(data, crs=crs, geometry=geometry)
geo_df.head()
# Out:
#   Componente ambiental            matriz  ... Thionazin                geometry
# 1                 Agua  Agua subterránea  ...         -  POINT (202143 8117057)
# 2                 Agua  Agua subterránea  ...         -  POINT (201861 8117035)
# 3                 Agua  Agua superficial  ...         -  POINT (191976 8107277)
# 4                 Agua  Agua superficial  ...        <1  POINT (208989 8111680)
# 6                 Agua  Agua superficial  ...         -  POINT (205234 8110983)
#
# [5 rows x 133 columns]

# %%
# %matplotlib inline
geo_df.plot()

# %%
import folium

# %%
mapa = folium.Map([-8.783333, -74.866667], zoom_start=4, tiles='cartodbpositron')
points = folium.features.GeoJson(gjson)
mapa.add_children(points)
mapa
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-429447b18254> in <module>()
#       1 mapa = folium.Map([-8.783333, -74.866667], zoom_start=4, tiles='cartodbpositron')
# ----> 2 points = folium.features.GeoJson(gjson)
#       3 mapa.add_children(points)
#       4 mapa
#
# NameError: name 'gjson' is not defined
